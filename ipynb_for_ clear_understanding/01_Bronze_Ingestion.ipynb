# %% [markdown]
# #CVE LAKEHOUSE - Bronze Layer

# %% [markdown]
# ## Bronze Layer Configuration

# %%
from pyspark.sql.functions import col, to_timestamp, year
import time

PARQUET_SOURCE_PATH = "/Volumes/workspace/default/cve_lakehouse_data/2024_parquet.parquet"
TEMP_JSON_DIR = "/Volumes/workspace/default/cve_lakehouse_data/staging_json"
BRONZE_OUTPUT_PATH = "/Volumes/workspace/default/cve_lakehouse_data/bronze"
BRONZE_TABLE_NAME = "cve_lakehouse.bronze_records"
TARGET_YEAR = 2024

spark.conf.set("spark.sql.shuffle.partitions", "8")

print(f"Configuration loaded: {TARGET_YEAR} CVEs")
# Out:
# Configuration loaded: 2024 CVEs

# %% [markdown]
# ## Read Parquet and Stage JSON

# %%
start_time = time.time()

print("Reading from Parquet...")
df_raw = spark.read.format("parquet").load(PARQUET_SOURCE_PATH)

print("Converting to JSON format...")
try:
    dbutils.fs.rm(TEMP_JSON_DIR, recurse=True)
except:
    pass

df_raw.select("json_data").write.mode("overwrite").text(TEMP_JSON_DIR)
print("JSON staged successfully")
# Out:
# Reading from Parquet...
# Converting to JSON format...
# JSON staged successfully

# %% [markdown]
# ## Parse JSON to Structured Format

# %%
print("Reading as JSON...")
parquet_read_start = time.time()

df_parsed = spark.read.json(TEMP_JSON_DIR)
raw_count = df_parsed.count()

parquet_read_time = time.time() - parquet_read_start
print(f"Loaded and parsed {raw_count:,} records in {parquet_read_time:.2f}s")
# Out:
# Reading as JSON...
# Loaded and parsed 38,727 records in 1.54s

# %% [markdown]
# ## Filter to 2024 and Quality Checks

# %%
print("Filtering to 2024...")
filter_start = time.time()

date_col = col("cveMetadata.datePublished").cast("string")
df_parsed = df_parsed.withColumn("_datePublished_ts", to_timestamp(date_col))
df_2024 = df_parsed.filter(year(col("_datePublished_ts")) == TARGET_YEAR)

cnt_2024 = df_2024.count()
null_ids = df_2024.filter(col("cveMetadata.cveId").isNull()).count()
distinct_ids = df_2024.select("cveMetadata.cveId").distinct().count()

filter_time = time.time() - filter_start

print(f"\nData Quality Checks:")
print(f"Total: {raw_count:,}")
print(f"2024 filtered: {cnt_2024:,}")
print(f"Null IDs: {null_ids}")
print(f"Distinct IDs: {distinct_ids:,}")

assert cnt_2024 >= 30000, f"Too few rows: {cnt_2024:,}"
assert null_ids == 0, "Null IDs found"
assert distinct_ids == cnt_2024, "IDs not unique"
print("Quality checks passed")
# Out:
# Filtering to 2024...
#
# Data Quality Checks:
# Total: 38,727
# 2024 filtered: 32,924
# Null IDs: 0
# Distinct IDs: 32,924
# Quality checks passed

# %% [markdown]
# ##Write Bronze Delta

# %%
print("\nWriting to Delta...")
delta_start = time.time()

try:
    dbutils.fs.rm(BRONZE_OUTPUT_PATH, recurse=True)
except:
    pass

(df_2024
 .repartition(8)
 .write
 .format("delta")
 .mode("overwrite")
 .option("delta.columnMapping.mode", "name")
 .save(BRONZE_OUTPUT_PATH))

delta_time = time.time() - delta_start
print(f"Delta write completed in {delta_time:.2f}s")
# Out:
# Writing to Delta...
# Delta write completed in 3.73s

# %% [markdown]
# ##Cleanup and Summary

# %%
print("Cleaning up temp files...")
try:
    dbutils.fs.rm(TEMP_JSON_DIR, recurse=True)
except:
    pass

total_time = time.time() - start_time
print(f"\nTiming: Parse+read {parquet_read_time:.2f}s | Filter {filter_time:.2f}s | Delta {delta_time:.2f}s | Total {total_time:.2f}s")
print(f"\nDelta files written to: {BRONZE_OUTPUT_PATH}")
print(f"Records: {cnt_2024:,}")
# Out:
# Cleaning up temp files...
#
# Timing: Parse+read 1.54s | Filter 1.55s | Delta 3.73s | Total 36.98s
#
# Delta files written to: /Volumes/workspace/default/cve_lakehouse_data/bronze
# Records: 32,924

# %% [markdown]
# ##Register Bronze Table (ALTERNATIVE)

# %%
# Read Delta directly and register as temp view
df_bronze = spark.read.format("delta").load(BRONZE_OUTPUT_PATH)
df_bronze.createOrReplaceTempView("bronze_records")

print(f"Table available as: bronze_records")
print(f"Records: {df_bronze.count():,}")
# Out:
# Table available as: bronze_records
# Records: 32,924

# %% [markdown]
# ##Verification

# %%
print("Bronze Layer Verification\n")

# Show sample records
spark.sql("SELECT * FROM bronze_records LIMIT 5").show(truncate=False)

# Show specific columns
spark.sql("""
    SELECT 
        cveMetadata.cveId as CVE_ID,
        cveMetadata.datePublished as Published,
        cveMetadata.state as State
    FROM bronze_records
    LIMIT 10
""").show(truncate=False)

# Final count
final_count = spark.sql("SELECT COUNT(*) as total FROM bronze_records").collect()[0]['total']
print(f"\n🎉 Bronze Layer Complete: {final_count:,} records")
# Out:
# Bronze Layer Verification
#
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-----------------------+
# |containers                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |cveMetadata                                                                                                                                                                        |dataType  |dataVersion|_datePublished_ts      |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-----------------------+
# |{NULL, {NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, {2024-04-08T11:06:07.879Z, c09c270a-b464-47c1-9133-acb35b22c19a, @huntr_ai}, NULL, [{en, [{false, text/html, This CVE ID has been rejected or withdrawn by its CVE Numbering Authority as the vulnerability is not in distributable software.}], This CVE ID has been rejected or withdrawn by its CVE Numbering Authority as the vulnerability is not in distributable software.}], NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, {Vulnogram 0.1.0-dev, NULL, NULL}, NULL, NULL}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |{c09c270a-b464-47c1-9133-acb35b22c19a, @huntr_ai, CVE-2024-0968, 2024-03-02T21:38:41.309Z, 2024-04-08T11:06:07.879Z, 2024-01-26T18:14:20.990Z, 2024-04-08T11:06:07.879Z, REJECTED} |CVE_RECORD|5.0        |2024-03-02 21:38:41.309|
# |{NULL, {NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, {2024-08-21T23:54:07.622Z, 416baaa9-dc9f-4396-8d5f-8c081fb06d67, Linux}, NULL, [{en, NULL, This CVE ID has been rejected or withdrawn by its CVE Numbering Authority.}], NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |{416baaa9-dc9f-4396-8d5f-8c081fb06d67, Linux, CVE-2024-37353, 2024-06-21T10:18:10.995Z, 2024-08-21T23:54:07.622Z, 2024-06-21T10:13:16.289Z, 2024-08-21T23:54:07.622Z, REJECTED}    |CVE_RECORD|5.1        |2024-06-21 10:18:10.995|
# |{NULL, {NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, {2025-03-16T14:46:33.264Z, b15e7b5b-3da4-40ae-a43c-f7aa60e62599, Wordfence}, NULL, [{en, NULL, ** REJECT ** DO NOT USE THIS CANDIDATE NUMBER. ConsultIDs: CVE-2024-53752. Reason: This candidate is a reservation duplicate of CVE-2024-53752. Notes: All CVE users should reference CVE-2024-53752 instead of this candidate. All references and descriptions in this candidate have been removed to prevent accidental usage.}], NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |{b15e7b5b-3da4-40ae-a43c-f7aa60e62599, Wordfence, CVE-2024-11879, 2024-12-14T04:23:40.550Z, 2025-03-16T14:46:33.264Z, 2024-11-27T15:35:35.611Z, 2025-03-16T14:46:33.264Z, REJECTED}|CVE_RECORD|5.1        |2024-12-14 04:23:40.55 |
# |{[{NULL, NULL, NULL, {2024-08-01T17:41:15.527Z, af854a3a-2127-422b-91ae-364da2661108, CVE}, [{NULL, [x_transferred], https://android.googlesource.com/platform/frameworks/base/+/7b7fff1eb5014d12200a32ff9047da396c7ab6a4}, {NULL, [x_transferred], https://source.android.com/security/bulletin/2024-02-01}], NULL, CVE Program Container, NULL}, {[{[cpe:2.3:o:google:android:11.0:*:*:*:*:*:*:*, cpe:2.3:o:google:android:12.0:*:*:*:*:*:*:*, cpe:2.3:o:google:android:12.0l:*:*:*:*:*:*:*, cpe:2.3:o:google:android:13.0:*:*:*:*:*:*:*, cpe:2.3:o:google:android:14.0:*:*:*:*:*:*:*], unknown, android, google, [{NULL, NULL, affected, 11.0, NULL}, {NULL, NULL, affected, 12.0, NULL}, {NULL, NULL, affected, 12.0l, NULL}, {NULL, NULL, affected, 13.0, NULL}, {NULL, NULL, affected, 14.0, NULL}]}], [{{HIGH, LOCAL, HIGH, 7.4, HIGH, HIGH, HIGH, NONE, UNCHANGED, NONE, CVSS:3.1/AV:L/AC:H/PR:N/UI:N/S:U/C:H/I:H/A:H, 3.1}, NULL, NULL, NULL}, {NULL, NULL, {{NULL, CVE-2024-0035, [{NULL, none, NULL}, {no, NULL, NULL}, {NULL, NULL, total}], NULL, CISA Coordinator, 2024-02-17T05:33:00.574638Z, 2.0.3}, ssvc}, NULL}], [{[{CWE-476, CWE-476 NULL Pointer Dereference, en, CWE}]}], {2024-08-28T14:27:48.699Z, 134c704f-9b21-4f2e-91b3-4a467353bcc0, CISA-ADP}, NULL, NULL, CISA ADP Vulnrichment, NULL}], {[{NULL, NULL, NULL, unaffected, NULL, NULL, NULL, Android, NULL, NULL, NULL, Google, [{NULL, NULL, NULL, affected, 14, NULL}, {NULL, NULL, NULL, affected, 13, NULL}, {NULL, NULL, NULL, affected, 12L, NULL}, {NULL, NULL, NULL, affected, 12, NULL}, {NULL, NULL, NULL, affected, 11, NULL}]}], NULL, NULL, NULL, NULL, NULL, [{en, NULL, In onNullBinding of TileLifecycleManager.java, there is a possible way to launch an activity from the background due to a missing null check. This could lead to local escalation of privilege with no additional execution privileges needed. User interaction is not needed for exploitation.}], NULL, NULL, NULL, [{[{NULL, Elevation of privilege, en, NULL}]}], {2024-02-16T00:08:17.297Z, baff130e-b8d5-4e15-b3d3-c3cf5d5545c6, google_android}, [{NULL, NULL, https://android.googlesource.com/platform/frameworks/base/+/7b7fff1eb5014d12200a32ff9047da396c7ab6a4}, {NULL, NULL, https://source.android.com/security/bulletin/2024-02-01}], NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL}}|{baff130e-b8d5-4e15-b3d3-c3cf5d5545c6, google_android, CVE-2024-0035, 2024-02-16T00:08:17.297Z, NULL, 2023-11-16T22:59:15.399Z, 2024-08-28T14:27:48.699Z, PUBLISHED}               |CVE_RECORD|5.1        |2024-02-16 00:08:17.297|
# |{[{NULL, NULL, NULL, {2024-08-01T17:41:15.681Z, af854a3a-2127-422b-91ae-364da2661108, CVE}, [{NULL, [x_transferred], https://android.googlesource.com/platform/packages/modules/Bluetooth/+/7d0f696f450241d8ba7a168ba14fa7b75032f0c9}, {NULL, [x_transferred], https://source.android.com/security/bulletin/2024-03-01}], NULL, CVE Program Container, NULL}, {[{[cpe:2.3:o:google:android:12.0:-:*:*:*:*:*:*, cpe:2.3:o:google:android:12l:*:*:*:*:*:*:*, cpe:2.3:o:google:android:13.0:-:*:*:*:*:*:*, cpe:2.3:o:google:android:14.0:*:*:*:*:*:*:*], unknown, android, google, [{NULL, NULL, affected, 12.0, NULL}, {NULL, NULL, affected, 12l, NULL}, {NULL, NULL, affected, 13.0, NULL}, {NULL, NULL, affected, 14.0, NULL}]}], [{{LOW, NETWORK, NONE, 7.5, HIGH, HIGH, NONE, NONE, UNCHANGED, NONE, CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:N/A:N, 3.1}, NULL, NULL, NULL}, {NULL, NULL, {{NULL, CVE-2024-0045, [{NULL, none, NULL}, {yes, NULL, NULL}, {NULL, NULL, partial}], NULL, CISA Coordinator, 2024-03-11T19:41:19.949358Z, 2.0.3}, ssvc}, NULL}], [{[{CWE-20, CWE-20 Improper Input Validation, en, CWE}]}], {2024-08-27T17:29:04.372Z, 134c704f-9b21-4f2e-91b3-4a467353bcc0, CISA-ADP}, NULL, NULL, CISA ADP Vulnrichment, NULL}], {[{NULL, NULL, NULL, unaffected, NULL, NULL, NULL, Android, NULL, NULL, NULL, Google, [{NULL, NULL, NULL, affected, 14, NULL}, {NULL, NULL, NULL, affected, 13, NULL}, {NULL, NULL, NULL, affected, 12L, NULL}, {NULL, NULL, NULL, affected, 12, NULL}]}], NULL, NULL, NULL, NULL, NULL, [{en, NULL, In smp_proc_sec_req of smp_act.cc, there is a possible out of bounds read due to improper input validation. This could lead to remote (proximal/adjacent) information disclosure with no additional execution privileges needed. User interaction is not needed for exploitation.}], NULL, NULL, NULL, [{[{NULL, Information disclosure, en, NULL}]}], {2024-03-11T16:35:21.876Z, baff130e-b8d5-4e15-b3d3-c3cf5d5545c6, google_android}, [{NULL, NULL, https://android.googlesource.com/platform/packages/modules/Bluetooth/+/7d0f696f450241d8ba7a168ba14fa7b75032f0c9}, {NULL, NULL, https://source.android.com/security/bulletin/2024-03-01}], NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                  |{baff130e-b8d5-4e15-b3d3-c3cf5d5545c6, google_android, CVE-2024-0045, 2024-03-11T16:35:21.876Z, NULL, 2023-11-16T22:59:23.385Z, 2024-08-27T17:29:04.372Z, PUBLISHED}               |CVE_RECORD|5.1        |2024-03-11 16:35:21.876|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-----------------------+
#
# +--------------+------------------------+---------+
# |CVE_ID        |Published               |State    |
# +--------------+------------------------+---------+
# |CVE-2024-0968 |2024-03-02T21:38:41.309Z|REJECTED |
# |CVE-2024-37353|2024-06-21T10:18:10.995Z|REJECTED |
# |CVE-2024-11879|2024-12-14T04:23:40.550Z|REJECTED |
# |CVE-2024-0035 |2024-02-16T00:08:17.297Z|PUBLISHED|
# |CVE-2024-0045 |2024-03-11T16:35:21.876Z|PUBLISHED|
# |CVE-2024-0014 |2024-02-16T00:08:14.746Z|PUBLISHED|
# |CVE-2024-0151 |2024-04-24T17:12:43.184Z|PUBLISHED|
# |CVE-2024-0213 |2024-01-09T13:01:13.209Z|PUBLISHED|
# |CVE-2024-0167 |2024-02-12T18:23:44.036Z|PUBLISHED|
# |CVE-2024-0165 |2024-02-12T18:30:52.482Z|PUBLISHED|
# +--------------+------------------------+---------+
#
#
# 🎉 Bronze Layer Complete: 32,924 records

# %% [markdown]
# ##Register Bronze Table with Column Mapping

# %%
# Read existing Delta files
df_bronze = spark.read.format("delta").load(BRONZE_OUTPUT_PATH)

print(f"Delta table contains {df_bronze.count():,} records")

# Create schema if needed
spark.sql("CREATE SCHEMA IF NOT EXISTS cve_bronze")

# Drop existing table
spark.sql("DROP TABLE IF EXISTS cve_bronze.records")

# Create table with column mapping
spark.sql(f"""
CREATE TABLE cve_bronze.records
USING DELTA
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
AS SELECT * FROM delta.`{BRONZE_OUTPUT_PATH}`
""")

print("Table registered: cve_bronze.records")

# Verify
spark.sql("SELECT cveMetadata.cveId, cveMetadata.datePublished FROM cve_bronze.records LIMIT 5").show()
spark.sql("SELECT COUNT(*) as total_records FROM cve_bronze.records").show()
# Out:
# Delta table contains 32,924 records
# Table registered: cve_bronze.records
# +--------------+--------------------+
# |         cveId|       datePublished|
# +--------------+--------------------+
# | CVE-2024-5758|2024-06-08T06:54:...|
# |CVE-2024-46503| 2024-09-30T00:00:00|
# | CVE-2024-0015|2024-02-16T18:33:...|
# | CVE-2024-0018|2024-02-16T19:33:...|
# | CVE-2024-0033|2024-02-16T00:08:...|
# +--------------+--------------------+
#
# +-------------+
# |total_records|
# +-------------+
# |        32924|
# +-------------+
